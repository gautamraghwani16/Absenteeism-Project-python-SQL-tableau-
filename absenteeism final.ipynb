# %%
from absenteeism_module import *

# %%
pd.read_csv("Absenteeism_new_data.csv")
# Out:
#     ID  Reason for Absence        Date  Transportation Expense  \
# 0   22                  27  01/06/2018                     179
# 1   10                   7  04/06/2018                     361
# 2   14                  23  06/06/2018                     155
# 3   17                  25  08/06/2018                     179
# 4   14                  10  08/06/2018                     155
# 5   28                  11  11/06/2018                     225
# 6   16                   7  13/06/2018                     118
# 7   22                  27  13/06/2018                     179
# 8   34                  26  15/06/2018                     118
# 9   34                  10  20/06/2018                     118
# 10  23                  22  21/06/2018                     378
# 11  36                  19  21/06/2018                     118
# 12  12                  19  22/06/2018                     233
# 13  22                  27  22/06/2018                     179
# ...

# %% [markdown]
#  the name of the class that has been created by data scientist team is absenteeism_model
#  we must create an instance of this class name model
#  contains two argument
#  the file , containing a fined tuned finalised version of the logistic regression model
#  the second is the scaler its function is to scale the value from the absentise new data as was done when the machine learning model was train
#  it contains the statistical parameter needed to adjest the magnitude of all numbers we have in this data set

# %%
model = absenteeism_model('model','scaler')

# %%
model.load_and_clean_data('Absenteeism_new_data.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.load_and_clean_data('Absenteeism_new_data.csv')
#
# File ~\Downloads\absenteeism model machine learningg\absenteeism_module.py:79, in absenteeism_model.load_and_clean_data(self, data_file)
#      74 # assign names to the 4 reason type columns
#      75 # note: there is a more universal version of this code, however the following will best suit our current purposes
#      76 column_names = ['Date', 'Transportation Expense', 'Distance to Work', 'Age',
#      77                'Daily Work Load Average', 'Body Mass Index', 'Education', 'Children',
#      78                'Pet', 'Absenteeism Time in Hours', 'Reason_1', 'Reason_2', 'Reason_3', 'Reason_4']
# ---> 79 df.columns = column_names
#      81 # re-order the columns in df
# ...

# %%
model.predicted_outputs()
